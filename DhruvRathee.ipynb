# %%
from transformers import pipeline
import torch
import torch.nn.functional as f
from langchain import LLMChain
from langchain.llms import HuggingFaceHub
from transformers import AutoModelForSequenceClassification
from dotenv import load_dotenv ,find_dotenv

apikey = "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"

from langchain.llms import HuggingFaceHub

# %%
from langchain.llms import OpenAI

from dotenv import load_dotenv , find_dotenv
import os 
os.environ["OPENAI_API_KEY"] = "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"
llm = OpenAI(temperature= 0)
# Out:
# /Users/arpitagnihotri/anaconda3/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %%
from langchain.llms import huggingface_hub

# %%
import os


from transformers import pipeline
os.environ['HUGGINGFACEHUB_API_TOKEN'] = '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'
from langchain import HuggingFaceHub, PromptTemplate , LLMChain
from transformers import pipeline
template = """  Question :{'Next script'}
Answer : Lets think step by step"""
prompt = PromptTemplate(template = template , input_variables= {'questions'})
llmchain_1 = LLMChain(prompt = prompt , llm= HuggingFaceHub(repo_id= "google/flan-t5-base"))
# Out:
# /Users/arpitagnihotri/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %%
from langchain.llms import HuggingFacePipeline
import torch
from transformers import AutoTokenizer,AutoModelForCausalLM,pipeline,AutoModelForSeq2SeqLM
model_id = "google/flan-t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %%
from langchain import HuggingFaceHub , PromptTemplate, LLMChain
from transformers import pipeline
template = """ Questions : {'questions'}
Answer:    """
prompt = PromptTemplate(template = template ,input_variables={'questions'} )
llmchain_2 = LLMChain(prompt = prompt , llm= HuggingFaceHub(repo_id= "google/flan-t5-base"))
# Out:
# /Users/arpitagnihotri/anaconda3/lib/python3.11/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'InferenceApi' (from 'huggingface_hub.inference_api') is deprecated and will be removed from version '1.0'. `InferenceApi` client is deprecated in favor of the more feature-complete `InferenceClient`. Check out this guide to learn how to convert your script to use it: https://huggingface.co/docs/huggingface_hub/guides/inference#legacy-inferenceapi-client.
#   warnings.warn(warning_message, FutureWarning)

# %%
from llama_index import SimpleDirectoryReader , VectorStoreIndex

# %%
#Content creation chatbot using youtube Video

# %%
from llama_hub.youtube_transcript import YoutubeTranscriptReader

loader = YoutubeTranscriptReader()
documents_1 = loader.load_data(ytlinks=['https://www.youtube.com/watch?v=hdiH5PIzR00'])

# %%
from llama_hub.youtube_transcript import YoutubeTranscriptReader

loader = YoutubeTranscriptReader()
documents_2 = loader.load_data(ytlinks=['https://www.youtube.com/watch?v=xGjZ98_JLR8'])

# %%
import pandas as pd

# %%
print(documents_1,documents_2)
# Out:
# [Document(id_='28c31802-c2b3-4f3c-8312-33799282aafd', embedding=None, metadata={'video_id': 'hdiH5PIzR00'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Hello, friends!\n16th August, 1945.\nWorld War II was on the verge of ending.\nJapan had laid down their weapons and surrendered.\nAnd in Germany, Hitler took his own life.\nGermany and Japan, both countries\nhad lost this war terribly.\nNetaji Subhash Chandra Bose,\nwho was taking Japan\'s help to \nlead the Indian National Army since 1943,\nwas looking for new ways\nto continue the freedom struggle.\nEven though the plans weren\'t properly laid out,\nhis associates knew that\nNetaji wanted to shift his base into the Soviet Union.\nHis plan was to first go to Tokyo\nto thank the Japanese Government\nand leave for Soviet from there.\nThe reason for this was very simple.\nThe Soviet Union was a part of the Allied Forces.\nThe countries that won this war.\nBut despite this, the Soviet was\nide
# ...

# %%
pip install langchainhub
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain import hub
obj = hub.pull("muhsinbashir/youtube-transcript-to-article")

# %%
print(obj)
# Out:
# input_variables=['transcript'] template="Act as an expert copywriter specializing in content optimization for SEO. Your task is to take a given YouTube transcript and transform it into a well-structured and engaging article. Your objectives are as follows:\n\nContent Transformation: Begin by thoroughly reading the provided YouTube transcript. Understand the main ideas, key points, and the overall message conveyed.\n\nSentence Structure: While rephrasing the content, pay careful attention to sentence structure. Ensure that the article flows logically and coherently.\n\nKeyword Identification: Identify the main keyword or phrase from the transcript. It's crucial to determine the primary topic that the YouTube video discusses.\n\nKeyword Integration: Incorporate the identified keyword naturally throughout the article. Use it in headings, subheadings, and within the body text. However, avoid overuse or keyword stuffing, as this can negatively affect SEO.\n\nUnique Content: Your goal is t
# ...

# %%
pip - install langchain openai tiktoken chromadb pypdf sentence_transformers InstructorEmbedding
# Out:
# ERROR: unknown command "-"
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.llms import OpenAI
from langchain.chains import RetrievalQA
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import DirectoryLoader

# %%
from InstructorEmbedding import INSTRUCTOR
from langchain.embeddings import HuggingFaceInstructEmbeddings

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
pip install docs
pip install docx
# Out:
#   Cell In[51], line 1
#     pip install docs
#         ^
# SyntaxError: invalid syntax

# %%
pip install docx2pdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx2pdf import convert

# Convert the Word document to PDF
convert('document_1')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[54], line 4
#       1 from docx2pdf import convert
#       3 # Convert the Word document to PDF
# ----> 4 convert('document_1')
#
# File ~/anaconda3/lib/python3.11/site-packages/docx2pdf/__init__.py:102, in convert(input_path, output_path, keep_active)
#     101 def convert(input_path, output_path=None, keep_active=False):
# --> 102     paths = resolve_paths(input_path, output_path)
#     103     if sys.platform == "darwin":
#     104         return macos(paths, keep_active)
#
# File ~/anaconda3/lib/python3.11/site-packages/docx2pdf/__init__.py:89, in resolve_paths(input_path, output_path)
#      87 else:
#      88     output["batch"] = False
# ---> 89     assert str(input_path).endswith(".docx")
#      90     output["input"] = str(input_path)
#      91     if output_path and output_path.is_dir():
#
# AssertionError:

# %%
from docx import Document

# Create a new document
document = Document()

# Add a heading to the document
document.add_heading('')

# Add a paragraph to the document
document.add_paragraph('This is a paragraph in my document.')

# Save the document
document.save('my_document.docx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 from docx import Document
#       3 # Create a new document
#       4 document = Document()
#
# ModuleNotFoundError: No module named 'docx'

# %%
text_splitter = RecursiveCharacterTextSplitter(
                                               chunk_size=1000, 
                                               chunk_overlap=200)

texts = text_splitter(documents_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       1 text_splitter = RecursiveCharacterTextSplitter(
#       2                                                chunk_size=1000,
#       3                                                chunk_overlap=200)
# ----> 5 texts = text_splitter(documents_1)
#
# TypeError: 'RecursiveCharacterTextSplitter' object is not callable

# %%
from langchain.text_splitter import CharacterTextSplitter

text_splitter = CharacterTextSplitter(
    separator="\n\n",
    chunk_size=1000,
    chunk_overlap=200,
    length_function=len,
    is_separator_regex=False,
)

# %%
from langchain.text_splitter import NLTKTextSplitter

text_splitter = NLTKTextSplitter(chunk_size=1000)

# %%
texts = text_splitter.split_text(documents_2)
print(texts[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 texts = text_splitter.split_text(documents_2)
#       2 print(texts[0])
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/text_splitter.py:1396, in NLTKTextSplitter.split_text(self, text)
#    1394 """Split incoming text and return chunks."""
#    1395 # First we naively split the large input into a bunch of smaller ones.
# -> 1396 splits = self._tokenizer(text, language=self._language)
#    1397 return self._merge_splits(splits, self._separator)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tokenize/__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
# ...

# %%
from llama_index.llama_pack import download_llama_pack

# download and install dependencies
OllamaQueryEnginePack = download_llama_pack(
    "OllamaQueryEnginePack", "./ollama_pack"
)

# You can use any llama-hub loader to get documents!
ollama_pack = OllamaQueryEnginePack(model="llama2", documents=documents_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 9
#       4 OllamaQueryEnginePack = download_llama_pack(
#       5     "OllamaQueryEnginePack", "./ollama_pack"
#       6 )
#       8 # You can use any llama-hub loader to get documents!
# ----> 9 ollama_pack = OllamaQueryEnginePack(model="llama2", documents=documents_2)
#
# File ~/Chat_models/ollama_pack/base.py:32, in OllamaQueryEnginePack.__init__(self, model, base_url, documents)
#      29 service_context = ServiceContext.from_defaults(llm=llm, embed_model=embed_model)
#      31 self.llm = llm
# ---> 32 self.index = VectorStoreIndex.from_documents(
#      33     documents, service_context=service_context
#      34 )
#
# File ~/anaconda3/lib/python3.11/site-packages/llama_index/indices/base.py:112, in BaseIndex.from_documents(cls, documents, storage_context, service_context, show_progress, **kwargs)
# ...

# %%
print(documents_2)
# Out:
# [Document(id_='d0eea7b4-bce4-4ff7-bf6b-a2a1e4bf7590', embedding=None, metadata={'video_id': 'xGjZ98_JLR8'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Hello, friends!\nOn 9th February 1943,\na German submarine departed \nfrom the city of Kiel, Germany.\nAlthough it carried the Nazi soldiers in it,\nan Indian was also present among them.\nAn Indian whose name was Matsuda.\nThis submarine was tasked with \nthe mission to travel Southward,\nto go around Africa\nand transfer Mr. Matsuda to a Japanese submarine.\nIt sounds easy,\nbut it was not without danger\nThe sea route was full of British ships.\nAnd this was during the World War II\nwhen Germany and Japan \nwere fighting against the British.\nOn 26th April 1943,\nafter a journey of about two and a half months,\nwhen this German submarine \nreached the coast of Madagascar,\na Japanese submarine was spotted in front of it.\nBut the sea was so stormy that\nit could have been dangerous for \n
# ...

# %%
my_list = documents_1
my_string = str(my_list)

# %%
my_list = [documents_1,documents_2]
my_string = " ".join(my_list)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 my_list = [documents_1,documents_2]
# ----> 2 my_string = " ".join(my_list)
#
# TypeError: sequence item 0: expected str instance, list found

# %%
texts = text_splitter.split_text([my_string])
print(texts[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 texts = text_splitter.split_text([my_string])
#       2 print(texts[0])
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/text_splitter.py:302, in CharacterTextSplitter.split_text(self, text)
#     298 # First we naively split the large input into a bunch of smaller ones.
#     299 separator = (
#     300     self._separator if self._is_separator_regex else re.escape(self._separator)
#     301 )
# --> 302 splits = _split_text_with_regex(text, separator, self._keep_separator)
#     303 _separator = "" if self._keep_separator else self._separator
#     304 return self._merge_splits(splits, _separator)
#
# File ~/anaconda3/lib/python3.11/site-packages/langchain/text_splitter.py:92, in _split_text_with_regex(text, separator, keep_separator)
#      90         splits = [_splits[0]] + splits
# ...

# %%
from llama_hub.tools.wolfram_alpha import WolframAlphaToolSpec
from llama_index.agent import OpenAIAgent


wolfram_spec = WolframAlphaToolSpec(app_id="API-key")

agent = OpenAIAgent.from_tools(wolfram_spec.to_tool_list(), verbose=True)

# %%
from langchain.embeddings import HuggingFaceEmbeddings,HuggingFaceInstructEmbeddings

# %%
documents_1
# Out:
# [Document(id_='28c31802-c2b3-4f3c-8312-33799282aafd', embedding=None, metadata={'video_id': 'hdiH5PIzR00'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Hello, friends!\n16th August, 1945.\nWorld War II was on the verge of ending.\nJapan had laid down their weapons and surrendered.\nAnd in Germany, Hitler took his own life.\nGermany and Japan, both countries\nhad lost this war terribly.\nNetaji Subhash Chandra Bose,\nwho was taking Japan\'s help to \nlead the Indian National Army since 1943,\nwas looking for new ways\nto continue the freedom struggle.\nEven though the plans weren\'t properly laid out,\nhis associates knew that\nNetaji wanted to shift his base into the Soviet Union.\nHis plan was to first go to Tokyo\nto thank the Japanese Government\nand leave for Soviet from there.\nThe reason for this was very simple.\nThe Soviet Union was a part of the Allied Forces.\nThe countries that won this war.\nBut despite this, the Soviet was\nide
# ...

# %%
#from google.colab import drive
#drive.mount('/content/gdrive', force_remount=True)
#root_dir = "/content/gdrive/My Drive"

# %%
#loader = DirectoryLoader(f'{root_dir}/Documents/', glob="./*.pdf", loader_cls=PyPDFLoader)
#documents = loader.load()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 2
#       1 #loader = DirectoryLoader(f'{root_dir}/Documents/', glob="./*.pdf", loader_cls=PyPDFLoader)
# ----> 2 documents = loader.load()
#
# AttributeError: 'YoutubeTranscriptReader' object has no attribute 'load'

# %%
pip install InstructorEmbedding
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.embeddings import HuggingFaceInstructEmbeddings

instructor_embeddings = HuggingFaceInstructEmbeddings(model_name="google/flan-t5-base", 
                                                      model_kwargs={"device": "cuda"})
# Out:
# .gitattributes:   0%|          | 0.00/1.43k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/13.4k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.40k [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# ...

# %%
index = VectorStoreIndex(documents_2)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 index = VectorStoreIndex(documents_2)
#
# File ~/anaconda3/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:53, in VectorStoreIndex.__init__(self, nodes, objects, index_struct, service_context, storage_context, use_async, store_nodes_override, insert_batch_size, show_progress, **kwargs)
#      51 self._store_nodes_override = store_nodes_override
#      52 self._insert_batch_size = insert_batch_size
# ---> 53 super().__init__(
#      54     nodes=nodes,
#      55     index_struct=index_struct,
#      56     service_context=service_context,
#      57     storage_context=storage_context,
#      58     show_progress=show_progress,
#      59     objects=objects,
#      60     **kwargs,
#      61 )
#
# ...

# %%
pip install transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence_transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
 from llama_index import service_context

# %%
from llama_index.prompts.prompts import SimpleInputPrompt

# %%
system = """ You are an assistant to help us creating content in short for, . With in 100 to 200 words for you tube """

# %%
print(documents_1,documents_2)
# Out:
# [Document(id_='28c31802-c2b3-4f3c-8312-33799282aafd', embedding=None, metadata={'video_id': 'hdiH5PIzR00'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='Hello, friends!\n16th August, 1945.\nWorld War II was on the verge of ending.\nJapan had laid down their weapons and surrendered.\nAnd in Germany, Hitler took his own life.\nGermany and Japan, both countries\nhad lost this war terribly.\nNetaji Subhash Chandra Bose,\nwho was taking Japan\'s help to \nlead the Indian National Army since 1943,\nwas looking for new ways\nto continue the freedom struggle.\nEven though the plans weren\'t properly laid out,\nhis associates knew that\nNetaji wanted to shift his base into the Soviet Union.\nHis plan was to first go to Tokyo\nto thank the Japanese Government\nand leave for Soviet from there.\nThe reason for this was very simple.\nThe Soviet Union was a part of the Allied Forces.\nThe countries that won this war.\nBut despite this, the Soviet was\nide
# ...

# %%
OllamaQueryEnginePack
# Out:
# custom_module.OllamaQueryEnginePack

# %%
import os 
os.environ['HUGGINGFACEHUB_API_TOKEN'] = os.getenv('HUGGINGFACEHUB_API_TOKEN')

# %%
from llama_index import ServiceContext

# %%
#define LLM: https://gpt-index.readthedocs.io/en/latest/core_modules/model_modules/llms/usage_custom.html
llm = OpenAI(model="gpt-4", temperature=0, max_tokens=256)

# configure service context
service_context = ServiceContext.from_defaults(llm=llm, chunk_size=800, chunk_overlap=20)
# set_global_service_context(service_context)
#index = VectorStoreIndex.from_documents(documents_1, service_context=service_context)

# %%
index = VectorStoreIndex(documents_1)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 index = VectorStoreIndex(documents_1)
#
# File ~/anaconda3/lib/python3.11/site-packages/llama_index/indices/vector_store/base.py:53, in VectorStoreIndex.__init__(self, nodes, objects, index_struct, service_context, storage_context, use_async, store_nodes_override, insert_batch_size, show_progress, **kwargs)
#      51 self._store_nodes_override = store_nodes_override
#      52 self._insert_batch_size = insert_batch_size
# ---> 53 super().__init__(
#      54     nodes=nodes,
#      55     index_struct=index_struct,
#      56     service_context=service_context,
#      57     storage_context=storage_context,
#      58     show_progress=show_progress,
#      59     objects=objects,
#      60     **kwargs,
#      61 )
#
# ...
